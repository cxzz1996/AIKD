# %%
import pandas as pd
import numpy as np
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from os import listdir,chdir
from os.path import isfile, join
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
location = r'C:\Users\Administrator\Desktop\AIproject'
allfiles = [i for i in listdir(location) if isfile(join(location, i))]

df = pd.read_csv(join(location, onlyfiles[0]),names=['content'],sep='\t',encoding='utf-8')

for i in onlyfiles[1:30]:
    df_news_temp = pd.read_csv(join(location, i),names=['content'],sep='\t',encoding='utf-8')
    df = df.append(df_news_temp,ignore_index = True)

df = df.reset_index(drop=True)
df['category']=['football','football','football','tennis','tennis','tennis','thelifeproject','thelifeproject','thelifeproject','housing','housing','housing','food','food','food','discovery','discovery','discovery','planet','planet','planet','vaccine','vaccine','vaccine','film','film','film','music','music','music']
df['theme']=['Paul Pogba Man Utd boss Ole Gunnar Solskjaer says midfielder is focused on club','Zlatan Ibrahimovic AC Milan striker vows to keep going','Deschamps defamation case against Cantona ruled void','Andy Lapthorne British wheelchair tennis player criticises sport for ableism','Andy Murray says tennis players should probably be required to take Covid vaccine','Australian Open 2021 Short delay to Grand Slam likely says government minister','How young workers are changing the rules of business speak','Could young workers change the future of labour','Why the pandemic is causing spikes in break-ups and divorces','How communal-living groups are riding out the pandemic','The city where you pay a years rent up front','The housing project where young and old must mingle','Indias beloved gargantuan bread','The US forgotten High South cuisine','Have you ever experienced shemomechama','A part of the Earth few ever see_discovery','The discovery of a lost, ancient world_discovery','The wine windows of Florence_discovery','Can dairy adapt to climate change','How Ireland is abandoning its dirty fuel','The nation learning to embrace flooding','Why you really dont want to catch Covid-19','The controversial cells that saved 10 million lives','The strange ingredients found in vaccines','News of the World is a beautifully old-fashioned Western','Why Hollywood gets the Irish so wrong','David Fincher Hollywoods most disturbing director','Blinding Light The Great American Painting','The fine line between art and pornography','The School of Athens A detail hidden in a masterpiece']
df
# Out:
#                                                                                                 content  \
# 0   Paul Pogba is focused on doing well for Manchester United despite his agent's comments about wan...
# 1   Zlatan Ibrahimovic football  says he is not ready to walk football away from football just yet a...
# 2   A defamation case brought by France's football team manager Didier Deschamps against his former ...
# 3   British wheelchair tennis player Andy tennis Lapthorne says events are being organised by people...
# 4   Andy Murray thinks tennis players should "probably" be required to take a Covid-19 vaccine to be...
# 5   The Australian Open is expected to be postponed by one or two weeks, says a Victoria government ...
# 6   Professional communication has traditionally been buttoned up. But a new generation entering the...
# 7   The pandemic is boosting young workers’ interest in labour unions. Could this reverse thelifepro...
# ...

# %%
content=df.content.values.tolist()
print(content[0])
# Out:
# Paul Pogba is focused on doing well for Manchester United despite his agent's comments about wanting to leave, says manager Ole Gunnar Solskjaer.Mino Raiola said this week Pogba had no interest in signing an extension to his contract, which ends in June 2022.He added it would be better for all parties if Pogba left in January."Paul's got the hunger and appetite to play. He wants to train and he's focused on performing when he gets a chance," said Solskjaer.No panic for Man Utd - SolskjaerIt is not entirely clear who has the money to pay the kind of fee United would want, although Pogba's former club Juventus have football repeatedly football been mentioned as being interested in the 27-year-old France World Cup winner.Solskjaer had offered curt answers when questioned about Pogba since Tuesday's Champions League elimination by RB Leipzig, when the midfielder was introduced as a second-half substitute.But when questioned about the matter on Friday, Solskjaer said Pogba's football atti
# ...

# %%
content_segment = []
for line in content:
    segment=word_tokenize(line)
    content_segment.append(segment)

# %%
        content_S[0]
# Out:
# ['Paul',
#  'Pogba',
#  'is',
#  'focused',
#  'on',
#  'doing',
#  'well',
#  'for',
#  'Manchester',
#  'United',
#  'despite',
#  'his',
#  'agent',
#  "'s",
#  'comments',
#  'about',
#  'wanting',
#  'to',
#  'leave',
#  ',',
#  'says',
#  'manager',
#  'Ole',
#  'Gunnar',
#  'Solskjaer.Mino',
#  'Raiola',
#  'said',
#  'this',
#  'week',
#  'Pogba',
#  'had',
#  'no',
#  'interest',
#  'in',
#  'signing',
#  'an',
#  'extension',
#  'to',
#  'his',
#  'contract',
#  ',',
#  'which',
#  'ends',
#  'in',
#  'June',
#  '2022.He',
#  'added',
#  'it',
#  'would',
#  'be',
#  'better',
#  'for',
#  'all',
#  'parties',
#  'if',
#  'Pogba',
#  'left',
#  'in',
#  'January',
#  '.',
#  '``',
#  'Paul',
#  "'s",
#  'got',
#  'the',
#  'hunger',
#  'and',
#  'appetite',
#  'to',
#  'play',
#  '.',
#  'He',
#  'wants',
#  'to',
#  'train',
#  'and',
#  'he',
#  "'s",
#  'focused',
#  'on',
#  'performing',
#  'when',
#  'he',
#  'gets',
#  'a',
#  'chance',
#  ',',
#  "''",
#  'said',
# ...

# %%
df_content=pd.DataFrame({'content_S':content_S})

df_content
# Out:
#                                                                                               content_S
# 0   [Paul, Pogba, is, focused, on, doing, well, for, Manchester, United, despite, his, agent, 's, co...
# 1   [Zlatan, Ibrahimovic, football, says, he, is, not, ready, to, walk, football, away, from, footba...
# 2   [A, defamation, case, brought, by, France, 's, football, team, manager, Didier, Deschamps, again...
# 3   [British, wheelchair, tennis, player, Andy, tennis, Lapthorne, says, events, are, being, organis...
# 4   [Andy, Murray, thinks, tennis, players, should, ``, probably, '', be, required, to, take, a, Cov...
# 5   [The, Australian, Open, is, expected, to, be, postponed, by, one, or, two, weeks, ,, says, a, Vi...
# 6   [Professional, communication, has, traditionally, been, buttoned, up, ., But, a, new, generation...
# 7   [The, pandemic, is, boosting, young, workers, ’, interest, in, labour, unions, ., Could, this, r...
# ...

# %%
stopWords = set(stopwords.words('english'))
stopWords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
def drop_stopwords(df_segment,stopwords):
    contents_clean=[]
    for word in segment:
        if word in stopwords:
            continue
        line_clean.append(word)
    return contents_clean
df_content=pd.DataFrame({'contents_clean':contents_clean})
contents_clean[0]
# Out:
# ['Paul',
#  'Pogba',
#  'focused',
#  'well',
#  'Manchester',
#  'United',
#  'despite',
#  'agent',
#  "'s",
#  'comments',
#  'wanting',
#  'leave',
#  ',',
#  'says',
#  'manager',
#  'Ole',
#  'Gunnar',
#  'Solskjaer.Mino',
#  'Raiola',
#  'said',
#  'week',
#  'Pogba',
#  'interest',
#  'signing',
#  'extension',
#  'contract',
#  ',',
#  'ends',
#  'June',
#  '2022.He',
#  'added',
#  'would',
#  'better',
#  'parties',
#  'Pogba',
#  'left',
#  'January',
#  '.',
#  '``',
#  'Paul',
#  "'s",
#  'got',
#  'hunger',
#  'appetite',
#  'play',
#  '.',
#  'He',
#  'wants',
#  'train',
#  "'s",
#  'focused',
#  'performing',
#  'gets',
#  'chance',
#  ',',
#  "''",
#  'said',
#  'Solskjaer.No',
#  'panic',
#  'Man',
#  'Utd',
#  '-',
#  'SolskjaerIt',
#  'entirely',
#  'clear',
#  'money',
#  'pay',
#  'kind',
#  'fee',
#  'United',
#  'would',
#  'want',
#  ',',
#  'although',
#  'Pogba',
#  "'s",
#  'former',
#  'club',
#  'Juventus',
#  'football',
#  'repeatedly',
# ...

# %%
df_all_words=pd.DataFrame({'all_words':all_words})
df_all_words
# Out:
#        all_words
# 0           Paul
# 1          Pogba
# 2        focused
# 3           well
# 4     Manchester
# ...          ...
# 6338      writer
# 6339        sits
# 6340        near
# 6341      middle
# 6342    painting
#
# [6343 rows x 1 columns]

# %%
def create_words(data):
    words = []
    for index in range(len(data)):
        try:
            words.append( ' '.join(data[index]))
        except Exception:
            print(index)
    return words

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df_train['contents_clean'].values, df_train['label'].values, random_state=1)
train_words = create_words(x_train)
test_words = create_words(x_test)
test_words[0]
# Out:
# "Florence ’ wine portals 17th Century While Florence restaurant forced close due Covid , able keep one part business open form 17th-Century buchette del vino , “ wine holes ” . The buchette del vino , “ wine holes ” , became import Florence plague 1630 allowed safe sale wine food . Today , 180 socially distant , libation-serving windows 17th Century peppered throughout Italian city ; however , locals knew original function pandemic . Since lockdown , drawn people around world . For stories watch , The BBC Travel Show - every weekend BBC News Channel BBC World News . If liked story , sign weekly bbc.com features newsletter called `` The Essential List '' ."

# %%
print(train_words)
# Out:
# ["Tom Hanks Helena Zengel star `` thoroughly engaging '' adventure across Texas , `` among beautiful films year , '' writes Caryn James . Lovely first word 'd usually associate Western , suits News World , film tenderness core despite adventures action . Tom Hanks gives heartfelt unsentimental performance Captain Jefferson Kyle Kidd , Confederate veteran US Civil War . He reluctantly takes 10-year-old girl across Texas aunt uncle , captured raised six years Kiowa tribe murdered parents . The pairing Western codger young girl evokes John Ford ’ 1956 classic , film film film film film filmThe Searchers . In film , John Wayne ’ character rescues niece , kidnapped Comanches , preparing reject 's longer respectable white girl . It also brings mind True Grit , 1969 original Coen brothers ' witty 2010 version , girl hires US marshal", "Numerous vaccines made using cells , taken foetus 1960s . But use also created moral dilemma . In 1612 , streets Paris alive tantalising rumour - man achieve
# ...

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer(analyzer = 'word',max_features=4000,lowercase=False)
vec.fit(train_words)
classifier = MultinomialNB()
classifier.fit(vec.transform(train_words),y_train)

predictions = classifier.predict(vec.transform(test_words))
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

print("Precision score: ", precision_score(y_test, predictions, average = 'weighted'))
predictions
# Out:
# Precision score:  0.875
# D:\ana\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# array(['football', 'vaccine', 'housing', 'planet', 'food', 'planet',
#        'film', 'tennis'], dtype='<U14')

# %%
df_test=pd.DataFrame()
df_test['context']=test_words
df_test['catagory']=predictions
df_test.to_csv('test.csv') 
df_test
# Out:
#                                                                                                context  \
# 0  Florence ’ wine portals 17th Century While Florence restaurant forced close due Covid , able kee...
# 1  From surprisingly treacherous path herd immunity potentially superior protection offered vaccine...
# 2  took fashion designer Folayemi Alade four months find apartment rent housing housing housing hou...
# 3  Peat bogs played historic role Ireland ’ economy culture , high-carbon fuel fast decline . How I...
# 4  In Georgia , known epic feasts toasts , people often experience shemomechama , untranslatable wo...
# 5  As climate change set make flooding worse Bangladesh , researchers racing find adaptations balan...
# 6  With films including Se7en , Zodiac Fight Club , David Fincher explored darkest edges humanity ....
# 7  British wheelchair tennis player Andy tennis Lapthorne says events organised people `` n't clue ...
#
#    catagory
# 0  football
# 1   vaccine
# ...

# %%
#Generate rdf
import rdflib
from rdflib.namespace import URIRef,RDF, RDFS
g = rdflib.Graph()

is_subclass_of = rdflib.URIRef('http://www.example.org/is_subclass_of')
is_part_of = rdflib.URIRef('http://www.example.org/is_part_of')

news1  = rdflib.URIRef('http://www.example.org/Andy Lapthorne British wheelchair tennis player criticises sport for ableism')
news2 = rdflib.URIRef('http://www.example.org/The city where you pay a years rent up front')
news3 = rdflib.URIRef('http://www.example.org/Have you ever experienced shemomechama')
news4 = rdflib.URIRef('http://www.example.org/The wine windows of Florence_discovery')
news5 = rdflib.URIRef('http://www.example.org/How Ireland is abandoning its dirty fuel')
news6 = rdflib.URIRef('http://www.example.org/The nation learning to embrace flooding')
news7 = rdflib.URIRef('http://www.example.org/Why you really dont want to catch Covid-19')
news8 = rdflib.URIRef('http://www.example.org/David Fincher Hollywoods most disturbing director')

sports = Namespace("http://xmlns.com/sports/")
worklife = Namespace("http://xmlns.com/worklife/")
travel = Namespace("http://xmlns.com/travel/")
future = Namespace("http://xmlns.com/future/")
culture = Namespace("http://xmlns.com/culture/")

g.add((news1, RDFS.subPropertyOf , sports.tennis))
g.add((news2, RDFS.subPropertyOf , worklife.housing))
g.add((news3, RDFS.subPropertyOf , travel.food))
g.add((news4, RDFS.subPropertyOf , sports.football))
g.add((news5, RDFS.subPropertyOf , future.planet))
g.add((news6, RDFS.subPropertyOf , future.planet))
g.add((news7, RDFS.subPropertyOf , future.vaccine))
g.add((news8, RDFS.subPropertyOf , culture.film))

g.serialize("rdf.rdf")
# Out:
# http://www.example.org/Andy Lapthorne British wheelchair tennis player criticises sport for ableism does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/The city where you pay a years rent up front does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/Have you ever experienced shemomechama does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/The wine windows of Florence_discovery does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/How Ireland is abandoning its dirty fuel does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/The nation learning to embrace flooding does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/Why you really dont want to catch Covid-19 does not look like a valid URI, trying to serialize this will break.
# ...
